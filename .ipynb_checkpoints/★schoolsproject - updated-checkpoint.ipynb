# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
#https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2ironhack&isDataTarget=false&bootcampId=10828&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'
#https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2Fironhack&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035,
'le-wagon' : 10868,
'udacity' : 11118,
'shecodes' : 11014
}


import re
import pandas as pd
from pandas.io.json import json_normalize
import requests

#pd.options.display.max_columns = None
#pd.options.display.max_rows = None

def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])

    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard
# le-wagon
# udacity
# shecodes

# %%
display(comments)
comments['school'].value_counts()
# Out:
#           id             name  anonymous hostProgramName  graduatingYear  \
# 0     306068        Anonymous       True            None          2023.0
# 1     305297      Utku Cikmaz      False            None          2023.0
# 2     305278     Nirmal Hodge      False            None          2023.0
# 3     305231        Anonymous       True            None          2023.0
# 4     305096        Anonymous       True            None          2023.0
# ...      ...              ...        ...             ...             ...
# 1393  250876   Sara Guerreiro      False            None          2019.0
# 1394  251528    Carmo Andrade      False            None          2019.0
# 1395  251115           Ângela      False            None          2019.0
# 1396  251215  Natalya Yarkova      False            None          2019.0
# 1397  247227        Anonymous       True            None          2019.0
#
#      isAlumni                        jobTitle  \
# ...

# %%
comments.columns.values.tolist()
# Out:
# ['id',
#  'name',
#  'anonymous',
#  'hostProgramName',
#  'graduatingYear',
#  'isAlumni',
#  'jobTitle',
#  'tagline',
#  'body',
#  'rawBody',
#  'createdAt',
#  'queryDate',
#  'program',
#  'user',
#  'overallScore',
#  'comments',
#  'overall',
#  'curriculum',
#  'jobSupport',
#  'review_body',
#  'school']

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9566 entries, 0 to 1397
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               9566 non-null   int64
#  1   name             9566 non-null   object
#  2   anonymous        9566 non-null   bool
#  3   hostProgramName  3720 non-null   object
#  4   graduatingYear   9557 non-null   float64
#  5   isAlumni         9554 non-null   object
#  6   jobTitle         5929 non-null   object
#  7   tagline          9565 non-null   object
#  8   body             9566 non-null   object
#  9   rawBody          9566 non-null   object
#  10  createdAt        9566 non-null   object
#  11  queryDate        9566 non-null   object
#  12  program          8566 non-null   object
#  13  user             9566 non-null   object
#  14  overallScore     9555 non-null   object
#  15  comments         9566 non-null   object
# ...

# %%
print(comments["program"].nunique())
print(comments["program"].unique())
# Out:
# 97
# [None 'Web Development Bootcamp' 'UX/UI Design Bootcamp'
#  'Web Development Part-Time' 'Data Analytics Part-Time'
#  'UX/UI Design Part-Time' 'Data Analytics Bootcamp'
#  'Cybersecurity Part-Time' 'Cyber Security Bootcamp' ''
#  'Full-time Web Development Bootcamp' 'Full-time UX/UI Design Bootcamp'
#  'Part-time Web Development' 'Part-time UX/UI Design'
#  'Full-time Web Development Bootcamp ' 'Part-time UX/UI Design '
#  'Web Design' '24-week Software Engineering Program (Full Time)'
#  '16-week Software Engineering Program'
#  '24-Week Online Full-Time Software Engineering Program'
#  '16-Week Campus Software Engineering Program' 'Bootcamp Prep'
#  'Software Engineer Track: Online' 'App Academy Open'
#  'Software Engineer Track: In-Person' 'UI/UX Design Career Track'
#  'Cyber Security Career Track' 'Data Science Career Track'
#  'Tech Sales Career Track' 'Software Engineering Career Track'
#  'UX Career Track' 'Data Analytics Career Track' 'Introduction to Design'
# ...

# %%
# Dropping unecessary columns

comments = comments.drop(columns=['anonymous', 'hostProgramName', 'body', 'rawBody','user','queryDate',"comments"])
comments
# Out:
#           id             name  graduatingYear isAlumni  \
# 0     306068        Anonymous          2023.0    False
# 1     305297      Utku Cikmaz          2023.0    False
# 2     305278     Nirmal Hodge          2023.0    False
# 3     305231        Anonymous          2023.0    False
# 4     305096        Anonymous          2023.0     True
# ...      ...              ...             ...      ...
# 1393  250876   Sara Guerreiro          2019.0     True
# 1394  251528    Carmo Andrade          2019.0     True
# 1395  251115           Ângela          2019.0     True
# 1396  251215  Natalya Yarkova          2019.0     True
# 1397  247227        Anonymous          2019.0     True
#
#                             jobTitle  \
# 0             Full stack development
# 1           Full Stack Web Developer
# 2                   Product Designer
# 3
# 4                    Web Development
# ...                              ...
# 1393  Event Marketing and Management
# ...

# %%
comments_cleaned = comments.dropna(subset=['program',"school", "overallScore", "overall", "curriculum", "jobSupport", "tagline", "createdAt"])

comments_cleaned
# Out:
#           id              name  graduatingYear isAlumni  \
# 1     305297       Utku Cikmaz          2023.0    False
# 2     305278      Nirmal Hodge          2023.0    False
# 3     305231         Anonymous          2023.0    False
# 4     305096         Anonymous          2023.0     True
# 5     305091     Sabir Karimov          2023.0    False
# ...      ...               ...             ...      ...
# 1389  251490             Joana          2019.0     True
# 1390  251131  Sofia Laranjeiro          2019.0     True
# 1391  250883       Sara Duarte          2019.0     True
# 1395  251115            Ângela          2019.0     True
# 1396  251215   Natalya Yarkova          2019.0     True
#
#                              jobTitle  \
# 1            Full Stack Web Developer
# 2                    Product Designer
# 3
# 4                     Web Development
# 5                        Data Analyst
# ...                               ...
# 1389                             None
# ...

# %%
# Function to cleam columns

import pandas as pd

def clean_columns(df, columns_to_clean):
    for column in columns_to_clean:
        # Convert the specified column to a numeric data type
        df.loc[:, column] = pd.to_numeric(df.loc[:, column], errors='coerce')
    
        # Check for and handle any non-numeric values (e.g., NaN)
        if df[column].isna().any():
            # You may choose to drop or handle rows with non-numeric values
            df.dropna(subset=[column], inplace=True)

    return df  # Return the updated DataFrame

# List of columns to clean
columns_to_clean = ["overallScore", "overall", "curriculum", "jobSupport"]

# Clean the specified columns
comments = clean_columns(comments, columns_to_clean)
# Out:
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\2776644238.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, column] = pd.to_numeric(df.loc[:, column], errors='coerce')
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\2776644238.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, column] = pd.to_numeric(df.loc[:, column], errors='coerce')
# ...

# %%
# Comparison by school

school_comparison = comments[["overallScore", "overall", "curriculum", "jobSupport", "school"]]
school_comparison = round(school_comparison.groupby("school").agg(["mean"]),2)
display(school_comparison)
# Out:
#             overallScore overall curriculum jobSupport
#                     mean    mean       mean       mean
# school
# app-academy         4.60    4.69       4.58       4.50
# ironhack            4.74    4.80       4.72       4.69
# le-wagon            4.91    4.98       4.95       4.81
# shecodes            4.87    4.97       4.94       4.71
# springboard         4.60    4.68       4.58       4.51
# udacity             4.40    4.58       4.56       4.06

# %%
# Comparison by school

import matplotlib.pyplot as plt

# Create a grouped bar chart
ax = school_comparison.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Metrics by School')
plt.xlabel('School')
plt.ylabel('Mean Value')
plt.xticks(rotation=45)
plt.legend(title='Metrics')

# Set the y-axis limits to display the range from 4 to 6
ax.set_ylim(4, 5)

plt.show()

# %%
# Comparison by school * program

school_program_comparison = comments[["overallScore", "overall", "curriculum", "jobSupport","school","program"]]
school_program_comparison = round(school_program_comparison.groupby(["school","program"]).agg(["mean", "count"]),2)
display(school_program_comparison)
# Out:
#                                                                overallScore  \
#                                                                        mean
# school      program
# app-academy                                                            4.42
#             16-Week Campus Software Engineering Program                4.82
#             16-week Software Engineering Program                       4.50
#             24-Week Online Full-Time Software Engineering P...         4.65
#             24-week Software Engineering Program (Full Time)           4.86
# ...                                                                     ...
# udacity     React                                                      3.66
#             Robotics Software Engineer                                 5.00
#             Self-Driving Car Engineer                                  5.00
#             UX Designer                                                4.92
# ...

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school


    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\2307708368.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# app-academy
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\2307708368.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# springboard
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\2307708368.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# le-wagon
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\2307708368.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# udacity
# ...

# %%
locations_list[0]
# Out:
#       id               description  country.id   country.name country.abbrev  \
# 0  15901           Berlin, Germany        57.0        Germany             DE
# 1  16022       Mexico City, Mexico        29.0         Mexico             MX
# 2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
# 3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
# 4  16109             Paris, France        38.0         France             FR
# 5  16375  Miami, FL, United States         1.0  United States             US
# 6  16376             Madrid, Spain        12.0          Spain             ES
# 7  16377          Barcelona, Spain        12.0          Spain             ES
# 8  16709          Lisbon, Portugal        28.0       Portugal             PT
# 9  17233                    Online         NaN            NaN            NaN
#
#    city.id    city.name city.keyword  state.id state.name state.abbrev  \
# ...

# %%
locations = pd.concat(locations_list)
display(locations)
locations.shape
# Out:
#        id                       description  country.id          country.name  \
# 0   15901                   Berlin, Germany        57.0               Germany
# 1   16022               Mexico City, Mexico        29.0                Mexico
# 2   16086            Amsterdam, Netherlands        59.0           Netherlands
# 3   16088                 Sao Paulo, Brazil        42.0                Brazil
# 4   16109                     Paris, France        38.0                France
# 5   16375          Miami, FL, United States         1.0         United States
# 6   16376                     Madrid, Spain        12.0                 Spain
# 7   16377                  Barcelona, Spain        12.0                 Spain
# 8   16709                  Lisbon, Portugal        28.0              Portugal
# 9   17233                            Online         NaN                   NaN
# 0   15704  San Francisco, CA, United States         1.0         United States
# ...

# %%
# Confirming the no.of countries by school 

countries_by_school = locations.groupby("school").agg(country_count=("country.name", "nunique")).reset_index()
countries_by_school
# Out:
#         school  country_count
# 0  app-academy              1
# 1     ironhack              8
# 2     le-wagon             22
# 3     shecodes              1
# 4  springboard              0
# 5      udacity              0

# %%
# Confirming the no.of cities by school 

locations_by_school = locations.groupby("school").agg(city_count=("city.name", "nunique")).reset_index()
locations_by_school
# Out:
#         school  city_count
# 0  app-academy           2
# 1     ironhack           9
# 2     le-wagon          37
# 3     shecodes           2
# 4  springboard           0
# 5      udacity           0

# %%
courses = pd.concat(courses_list)
courses.head(len(courses))
# Out:
#                      courses    school  school_id
# 0    Cyber Security Bootcamp  ironhack      10828
# 1    Cybersecurity Part-Time  ironhack      10828
# 2    Data Analytics Bootcamp  ironhack      10828
# 3   Data Analytics Part-Time  ironhack      10828
# 4      UX/UI Design Bootcamp  ironhack      10828
# ..                       ...       ...        ...
# 32               UX Designer   udacity      11118
# 0            SheCodes Basics  shecodes      11014
# 1               SheCodes Max  shecodes      11014
# 2              SheCodes Plus  shecodes      11014
# 3               SheCodes Pro  shecodes      11014
#
# [73 rows x 3 columns]

# %%
# Confirming the no.of courses by school 

courses_by_school = courses.groupby("school").agg(courses_count=("courses", "nunique")).reset_index()
courses_by_school
# Out:
#         school  courses_count
# 0  app-academy              7
# 1     ironhack              8
# 2     le-wagon              8
# 3     shecodes              4
# 4  springboard             13
# 5      udacity             33

# %%
badges = pd.concat(badges_list)
badges.head(len(badges))
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# ...

# %%
# Confirming the no.of courses by school 

badges_by_school = badges.groupby(["school"]).agg(badges_count=("name", "nunique")).reset_index()
badges_by_school
# Out:
#         school  badges_count
# 0  app-academy             3
# 1     ironhack             3
# 2     le-wagon             2
# 3     shecodes             2
# 4  springboard             3
# 5      udacity             2

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head(len(schools))
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0                                    www.lewagon.com
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
# 0                                        shecodes.io
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Le Wagon is a glo...
# 0  <span class="truncatable"><p>Udacity is the tr...
# 0  <span class="truncatable"><p>SheCodes is a cod...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# ...

# %%
# Comparison between Ironhack programs - by program  >>> Count is too small. Maybe useful if we compare Full-time vs. Part-tine or by courses (ex. DA vs. UX vs. WD)

ironhack_programs = comments[comments["school"]=="ironhack"]
ironhack_programs = round(ironhack_programs.groupby("program").agg(["mean","count"]),2)
display(ironhack_programs[["overallScore", "overall", "curriculum", "jobSupport"]])
# Out:
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\1141818537.py:4: FutureWarning: ['name', 'jobTitle', 'tagline', 'createdAt', 'review_body', 'school'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   ironhack_programs = round(ironhack_programs.groupby("program").agg(["mean","count"]),2)
#                                     overallScore       overall        \
#                                             mean count    mean count
# program
#                                             4.65    59    4.76    59
# Cyber Security Bootcamp                     4.28     6    4.17     6
# Cybersecurity Part-Time                     3.87     3    4.00     3
# Data Analytics Bootcamp                     4.46    57    4.56    57
# Data Analytics Part-Time                    4.30    22    4.45    22
# Full-time UX/UI Design Bootcamp             4.78   160    4.84   160
# ...

# %%
# Comparison between LeWagon programs

lewagon_programs = comments[comments["school"]=="le-wagon"]
lewagon_programs = round(lewagon_programs.groupby("program").agg(["mean","count"]),2)
display(lewagon_programs[["overallScore", "overall", "curriculum", "jobSupport"]])
# Out:
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\560191748.py:4: FutureWarning: ['name', 'jobTitle', 'tagline', 'createdAt', 'review_body', 'school'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   lewagon_programs = round(lewagon_programs.groupby("program").agg(["mean","count"]),2)
#                                    overallScore       overall        \
#                                            mean count    mean count
# program
#                                            4.89   125    4.94   125
# Data Analytics                             5.00     1    5.00     1
# Data Analytics - Full-Time                 4.65     2    5.00     2
# Data Science & AI - Full-Time              5.00     2    5.00     2
# Data Science - Full-Time                   4.90   189    4.98   189
# Data Science - Part-Time                   4.87    26    4.96    26
# ...

# %%
# Comparison between Shecodes programs

shecodes_programs = comments[comments["school"]=="shecodes"]
shecodes_programs = round(shecodes_programs.groupby("program").agg(["mean","count"]),2)
display(shecodes_programs[["overallScore", "overall", "curriculum", "jobSupport"]])
# Out:
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\4151232633.py:4: FutureWarning: ['name', 'jobTitle', 'tagline', 'createdAt', 'review_body', 'school'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   shecodes_programs = round(shecodes_programs.groupby("program").agg(["mean","count"]),2)
#                                                 overallScore       overall  \
#                                                         mean count    mean
# program
#                                                         4.80    88    4.95
# Full-Time, Full Stack Web Development Boot Camp         5.00     1    5.00
# SheCodes                                                4.80    70    4.97
# SheCodes Basics                                         4.89   549    4.98
# SheCodes Max                                            4.86     5    5.00
# ...

# %%
#Checking comments of shecodes to understand its features.
#comments[comments["school"]=="shecodes"]["review_body"].unique()

# %%
# Join comments dataframe and courses dataframe

#comments_updated = pd.merge(comments, courses, on='program', how='left')
#comments_updated = comments_updated.drop(['anonymous', 'hostProgramName', 'body', 'rawBody','queryDate','user',"comments"], axis=1)
#comments_updated

# %%
# Function to categorize program column >>> BUT THE OUTPUT IS NOT AS EXPECTED (ALL FALLS IN "FULL-TIME")

def aggregate_programs(df,column,new_column):
    for i in df[column]:
        if i == None:
            df[new_column]="n/a"
        elif "part-time" in i.lower() or "part time" in i.lower():
            df[new_column]="Part-Time"
        else:
            df[new_column]="Full-Time"
    return df

aggregate_programs(comments,"program","program_category")
display(comments)
# Out:
#           id              name  graduatingYear isAlumni  \
# 0     306068         Anonymous          2023.0    False
# 1     305297       Utku Cikmaz          2023.0    False
# 2     305278      Nirmal Hodge          2023.0    False
# 3     305231         Anonymous          2023.0    False
# 4     305096         Anonymous          2023.0     True
# ...      ...               ...             ...      ...
# 1390  251131  Sofia Laranjeiro          2019.0     True
# 1391  250883       Sara Duarte          2019.0     True
# 1393  250876    Sara Guerreiro          2019.0     True
# 1395  251115            Ângela          2019.0     True
# 1396  251215   Natalya Yarkova          2019.0     True
#
#                              jobTitle  \
# 0              Full stack development
# 1            Full Stack Web Developer
# 2                    Product Designer
# 3
# 4                     Web Development
# ...                               ...
# 1390                             None
# ...

# %%
# Comparison between Ironhack programs - by program category  >>> the function does not work(?)

ironhack_programs_2 = comments[comments["school"]=="ironhack"]
ironhack_programs_2 = round(ironhack_programs_2.groupby("program_category").agg(["mean","count"]),2)
display(ironhack_programs_2[["overallScore", "overall", "curriculum", "jobSupport"]])
# Out:
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_9328\1256252476.py:4: FutureWarning: ['name', 'jobTitle', 'tagline', 'createdAt', 'program', 'review_body', 'school'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   ironhack_programs_2 = round(ironhack_programs_2.groupby("program_category").agg(["mean","count"]),2)
#                  overallScore       overall       curriculum       jobSupport  \
#                          mean count    mean count       mean count       mean
# program_category
# Full-Time                4.74  1232     4.8  1232       4.72  1232       4.69
#
#
#                  count
# program_category
# Full-Time         1232

# %%
import mysql.connector
from getpass import getpass
from sqlalchemy import create_engine

# %%
from getpass import getpass

password = getpass()
cnx = mysql.connector.connect(user="root",
                              password=password,
                              host="localhost",
                              database="sakila")

cnx.is_connected()
# Out:
# ········
# True

# %%
# We need to define the object we will use to interact with mysql
cursor = cnx.cursor()

# %%
# Create a db

quary = ("""CREATE DATABASE project_school""")

cursor.execute(quary)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:639, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     638         query = query.encode("utf-8")
# --> 639     self._cmysql.query(
#     640         query,
#     641         raw=raw,
#     642         buffered=buffered,
#     643         raw_as_string=raw_as_string,
#     644         query_attrs=self.query_attrs,
#     645     )
#     646 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'project_school'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[35], line 5
#       1 # Create a db
#       3 quary = ("""CREATE DATABASE project_school""")
# ...

# %%
# Close the cursor
cursor.close()
# Out:
# True

# %%
password = getpass()
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=password,
                               db="project_school"))
# Out:
# ········

# %%
comments_cleaned.to_sql('comments', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 8021

# %%
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 56

# %%
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 73

# %%
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 15

# %%
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 15

# %%
import mysql.connector
from getpass import getpass
import pymysql
import pandas as pd
password = getpass()
connection = pymysql.connect(
    host='localhost',  # Replace with your MySQL host
    user='root',  # Replace with your MySQL username
    password= password,  # Replace with your MySQL password
    db='project_school',  # Replace with the name of your database
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)
try:
    with connection.cursor() as cursor:
        # Define your SQL query
        sql_query = """
SELECT project_school.comments.school, graduatingYear, ROUND(AVG(curriculum),2) AS avg_curriculum, ROUND(AVG(jobSupport),2) AS avg_jobsupport, COUNT(project_school.comments.school) AS number_students
FROM project_school.comments WHERE project_school.comments.school = "ironhack"
GROUP BY project_school.comments.school, graduatingYear
ORDER BY graduatingYear ASC;
        """
        # Execute the SQL query
        cursor.execute(sql_query)
        # Fetch all the results
        results = cursor.fetchall()
        # Print the results
        DataCurrJob = pd.DataFrame(results)
finally:
    # Close the connection
    connection.close()
# Out:
# ········

# %%
DataCurrJob
# Out:
#       school  graduatingYear  avg_curriculum  avg_jobsupport  number_students
# 0   ironhack          2011.0            4.00            5.00                1
# 1   ironhack          2014.0            4.75            4.62                8
# 2   ironhack          2015.0            4.71            4.88               17
# 3   ironhack          2016.0            4.89            4.89               56
# 4   ironhack          2017.0            4.82            4.91              179
# 5   ironhack          2018.0            4.82            4.90              288
# 6   ironhack          2019.0            4.70            4.79              211
# 7   ironhack          2020.0            4.77            4.57              183
# 8   ironhack          2021.0            4.58            4.34               83
# 9   ironhack          2022.0            4.48            4.22              109
# 10  ironhack          2023.0            4.25            3.98               44

# %%
# Convert the 'column_name' from float to int
DataCurrJob['graduatingYear'] =DataCurrJob['graduatingYear'].astype(int)

# Display the DataFrame
print(DataCurrJob)
# Out:
#       school  graduatingYear  avg_curriculum  avg_jobsupport  number_students
# 0   ironhack            2011            4.00            5.00                1
# 1   ironhack            2014            4.75            4.62                8
# 2   ironhack            2015            4.71            4.88               17
# 3   ironhack            2016            4.89            4.89               56
# 4   ironhack            2017            4.82            4.91              179
# 5   ironhack            2018            4.82            4.90              288
# 6   ironhack            2019            4.70            4.79              211
# 7   ironhack            2020            4.77            4.57              183
# 8   ironhack            2021            4.58            4.34               83
# 9   ironhack            2022            4.48            4.22              109
# 10  ironhack            2023            4.25            3.98               44

# %%
# Drop the number of students column

DataCurrJob_updated = DataCurrJob.drop("number_students", axis="columns")

# %%
import numpy as np
import matplotlib.pyplot as plt

DataCurrJob_updated.set_index('graduatingYear').plot();
