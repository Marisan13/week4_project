# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 7 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests


def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])

    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
#comments = []

#for school in schools.keys():
    #print(school)
    #comments.append(get_comments_school(school))

#comments = pd.concat(comments)

# %%
# could you write this as a list comprehension? ;)
comments = [get_comments_school(school) for school in schools.keys()]
comments = pd.concat(comments)

# %%
comments
# Out:
#           id           name  anonymous hostProgramName  graduatingYear  \
# 0     305297    Utku Cikmaz      False            None          2023.0
# 1     305278   Nirmal Hodge      False            None          2023.0
# 2     305231      Anonymous       True            None          2023.0
# 3     305096      Anonymous       True            None          2023.0
# 4     305091  Sabir Karimov      False            None          2023.0
# ...      ...            ...        ...             ...             ...
# 1547  234894   Stephanie S.      False            None          2015.0
# 1548  234877       Joe Fang      False            None          2015.0
# 1549  234838          Zeina      False            None          2016.0
# 1550  242681           Jean      False            None          2016.0
# 1551  234178            Ben      False            None          2016.0
#
#       isAlumni                         jobTitle  \
# 0        False         Full Stack Web Developer
# 1        False                 Product Designer
# 2        False
# 3         True                  Web Development
# 4        False                     Data Analyst
# ...        ...                              ...
# 1547      True          Website Manager-UX Lead
# 1548      True                      UX Designer
# 1549      True          Senior Graphic Designer
# 1550      True  Lead Designer/Creative Director
# 1551      True                             None
#
#                                                 tagline  \
# 0                                           It was good
# 1                               Ironhack 100% Worth It!
# 2                                Still waiting a refund
# 3     Transformative Learning Experience - A Review ...
# 4            A very frustrating yet exciting experience
# ...                                                 ...
# 1547              Excellent and comprehensive UX course
# 1548        Springboard helped me start my career in UX
# 1549                                 Highly recommended
# 1550    A way to stay current for the highly motivated!
# 1551  Springboard is an excellent course for self dr...
#
#                                                    body  \
# 0     <span class="truncatable"><p></p><p>The course...
# 1     <span class="truncatable"><p></p><p>I joined t...
# 2     <span class="truncatable"><p></p><p>Unfortunat...
# 3     <span class="truncatable"><p></p><p>I recently...
# 4     <span class="truncatable"><p></p><p>It was my ...
# ...                                                 ...
# 1547  <span class="truncatable"><p>The UX Design Wor...
# 1548  <span class="truncatable"><p>Just some backgro...
# 1549  <span class="truncatable"><p>I enjoyed the pro...
# 1550  <span class="truncatable"><p>This was my first...
# 1551  <span class="truncatable"><p>I really enjoyed ...
#
#                                                 rawBody  ...   queryDate  \
# 0     <p>The course was great. Especially, Luis is a...  ...  2023-10-02
# 1     <p>I joined the UX/ UI Bootcamp and to be hone...  ...  2023-09-30
# 2     <p>Unfortunately wouldn&rsquo;t recommend it. ...  ...  2023-09-28
# 3     <p>I recently completed the Web Dev part-time ...  ...  2023-09-22
# 4     <p>It was my first experience in programming a...  ...  2023-09-22
# ...                                                 ...  ...         ...
# 1547  The UX Design Workshop gave me a great underst...  ...  2016-12-15
# 1548  Just some background information on myself, I ...  ...  2016-12-15
# 1549  I enjoyed the program very much, gained a lot ...  ...  2016-12-15
# 1550  This was my first online experience and it did...  ...  2016-12-12
# 1551  I really enjoyed my time with the Springboard ...  ...  2016-12-10
#
#                         program             user overallScore comments  \
# 0      Web Development Bootcamp  {'image': None}          4.0       []
# 1         UX/UI Design Bootcamp  {'image': None}          5.0       []
# 2      Web Development Bootcamp  {'image': None}          1.0       []
# 3     Web Development Part-Time  {'image': None}          4.3       []
# 4      Data Analytics Part-Time  {'image': None}          4.3       []
# ...                         ...              ...          ...      ...
# 1547                  UX Design  {'image': None}          5.0       []
# 1548                  UX Design  {'image': None}          5.0       []
# 1549                  UX Design  {'image': None}          3.7       []
# 1550                  UX Design  {'image': None}          5.0       []
# 1551                  UX Design  {'image': None}          4.7       []
#
#      overall curriculum jobSupport  \
# 0        5.0        3.0        4.0
# 1        5.0        5.0        5.0
# 2        1.0        1.0        1.0
# 3        4.0        5.0        4.0
# 4        4.0        5.0        4.0
# ...      ...        ...        ...
# 1547     5.0        5.0        5.0
# 1548     5.0        5.0        5.0
# 1549     4.0        4.0        3.0
# 1550     5.0        5.0        5.0
# 1551     5.0        5.0        4.0
#
#                                             review_body       school
# 0     The course was great. Especially, Luis is a gr...     ironhack
# 1     I joined the UX/ UI Bootcamp and to be honest ...     ironhack
# 2     Unfortunately wouldn’t recommend it. Still wai...     ironhack
# 3     I recently completed the Web Dev part-time Boo...     ironhack
# 4     It was my first experience in programming and ...     ironhack
# ...                                                 ...          ...
# 1547  The UX Design Workshop gave me a great underst...  springboard
# 1548  Just some background information on myself, I ...  springboard
# 1549  I enjoyed the program very much, gained a lot ...  springboard
# 1550  This was my first online experience and it did...  springboard
# 1551  I really enjoyed my time with the Springboard ...  springboard
#
# [4032 rows x 21 columns]

# %%
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup


# Function to parse html and extract text
def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return soup.get_text()



def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    # Apply parse_html function to extract only text
    badges_df['description'] = badges_df['description'].apply(parse_html)

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']
    # Apply parse_html function to extract only text
    school_df['description']=school_df['description'].apply(parse_html)

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school


    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_11688\3195885777.py:20: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# app-academy
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_11688\3195885777.py:20: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# springboard
# C:\Users\mkcor\AppData\Local\Temp\ipykernel_11688\3195885777.py:20: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)

# %%
locations_list[0]
# Out:
#       id               description  country.id   country.name country.abbrev  \
# 0  15901           Berlin, Germany        57.0        Germany             DE
# 1  16022       Mexico City, Mexico        29.0         Mexico             MX
# 2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
# 3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
# 4  16109             Paris, France        38.0         France             FR
# 5  16375  Miami, FL, United States         1.0  United States             US
# 6  16376             Madrid, Spain        12.0          Spain             ES
# 7  16377          Barcelona, Spain        12.0          Spain             ES
# 8  16709          Lisbon, Portugal        28.0       Portugal             PT
# 9  17233                    Online         NaN            NaN            NaN
#
#    city.id    city.name city.keyword  state.id state.name state.abbrev  \
# 0  31156.0       Berlin       berlin       NaN        NaN          NaN
# 1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
# 2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
# 3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
# 4  31136.0        Paris        paris       NaN        NaN          NaN
# 5     31.0        Miami        miami      11.0    Florida           FL
# 6  31052.0       Madrid       madrid       NaN        NaN          NaN
# 7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
# 8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
# 9      NaN          NaN          NaN       1.0     Online       Online
#
#   state.keyword    school  school_id
# 0           NaN  ironhack      10828
# 1           NaN  ironhack      10828
# 2           NaN  ironhack      10828
# 3           NaN  ironhack      10828
# 4           NaN  ironhack      10828
# 5       florida  ironhack      10828
# 6           NaN  ironhack      10828
# 7           NaN  ironhack      10828
# 8           NaN  ironhack      10828
# 9        online  ironhack      10828

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# 2  15862                            Online         NaN            NaN
# 0  16013                            Online         NaN            NaN
#
#   country.abbrev  city.id      city.name   city.keyword  state.id  state.name  \
# 0             DE  31156.0         Berlin         berlin       NaN         NaN
# 1             MX  31175.0    Mexico City    mexico-city       NaN         NaN
# 2             NL  31168.0      Amsterdam      amsterdam       NaN         NaN
# 3             BR  31121.0      Sao Paulo      sao-paulo       NaN         NaN
# 4             FR  31136.0          Paris          paris       NaN         NaN
# 5             US     31.0          Miami          miami      11.0     Florida
# 6             ES  31052.0         Madrid         madrid       NaN         NaN
# 7             ES  31170.0      Barcelona      barcelona       NaN         NaN
# 8             PT  31075.0         Lisbon         lisbon       NaN         NaN
# 9            NaN      NaN            NaN            NaN       1.0      Online
# 0             US     13.0  San Francisco  san-francisco       6.0  California
# 1             US   1507.0            NYC  new-york-city      34.0    New York
# 2            NaN      NaN            NaN            NaN       1.0      Online
# 0            NaN      NaN            NaN            NaN       1.0      Online
#
#   state.abbrev state.keyword       school  school_id
# 0          NaN           NaN     ironhack      10828
# 1          NaN           NaN     ironhack      10828
# 2          NaN           NaN     ironhack      10828
# 3          NaN           NaN     ironhack      10828
# 4          NaN           NaN     ironhack      10828
# 5           FL       florida     ironhack      10828
# 6          NaN           NaN     ironhack      10828
# 7          NaN           NaN     ironhack      10828
# 8          NaN           NaN     ironhack      10828
# 9       Online        online     ironhack      10828
# 0           CA    california  app-academy      10525
# 1           NY      new-york  app-academy      10525
# 2       Online        online  app-academy      10525
# 0       Online        online  springboard      11035

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                                 courses       school  school_id
# 0               Cyber Security Bootcamp     ironhack      10828
# 1               Cybersecurity Part-Time     ironhack      10828
# 2               Data Analytics Bootcamp     ironhack      10828
# 3              Data Analytics Part-Time     ironhack      10828
# 4                 UX/UI Design Bootcamp     ironhack      10828
# 5                UX/UI Design Part-Time     ironhack      10828
# 6              Web Development Bootcamp     ironhack      10828
# 7             Web Development Part-Time     ironhack      10828
# 0  16-week Software Engineering Program  app-academy      10525
# 1                         Bootcamp Prep  app-academy      10525

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0                 School offers fully online courses     ironhack      10828
# 1  School publishes a third-party verified outcom...     ironhack      10828
# 2        School offers part-time and evening classes     ironhack      10828
# 0                 School offers fully online courses  app-academy      10525
# 1        School offers part-time and evening classes  app-academy      10525

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  Ironhack is a global tech school with 9 campus...
# 0  Founded in 2012, App Academy is a world-renown...
# 0  Springboard is an online learning platform tha...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035
